# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Usuario\Desktop\Billionaires Statistics Dataset.csv")
df.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# 0               France  ...                1.1   $2,715,518,274,227
# 1        United States  ...                7.5  $21,427,700,000,000
# 2        United States  ...                7.5  $21,427,700,000,000
# 3        United States  ...                7.5  $21,427,700,000,000
# 4        United States  ...                7.5  $21,427,700,000,000
#
#   gross_tertiary_education_enrollment  \
# 0                                65.6
# 1                                88.2
# 2                                88.2
# 3                                88.2
# 4                                88.2
#
#   gross_primary_education_enrollment_country life_expectancy_country  \
# 0                                      102.5                    82.5
# 1                                      101.8                    78.5
# 2                                      101.8                    78.5
# 3                                      101.8                    78.5
# 4                                      101.8                    78.5
#
#   tax_revenue_country_country total_tax_rate_country population_country  \
# 0                        24.2                   60.7         67059887.0
# 1                         9.6                   36.6        328239523.0
# 2                         9.6                   36.6        328239523.0
# 3                         9.6                   36.6        328239523.0
# 4                         9.6                   36.6        328239523.0
#
#   latitude_country longitude_country
# 0        46.227638          2.213749
# 1        37.090240        -95.712891
# 2        37.090240        -95.712891
# 3        37.090240        -95.712891
# 4        37.090240        -95.712891
#
# [5 rows x 35 columns]

# %%
df["age"].mean()
# Out:
# 65.14019417475728

# %%
# 65 is the average age of billionaires

# %%
df["age"].min()
# Out:
# 18.0

# %%
# The youngest billionaire is 18 years old

# %%
df.sort_values(by = "age")
# Out:
#       rank  finalWorth               category            personName   age  \
# 823    818        3500       Fashion & Retail  Clemente Del Vecchio  18.0
# 1755  1725        1700  Media & Entertainment         Kim Jung-youn  19.0
# 1334  1312        2300       Fashion & Retail   Kevin David Lehmann  20.0
# 825    818        3500       Fashion & Retail      Luca Del Vecchio  21.0
# 1754  1725        1700  Media & Entertainment          Kim Jung-min  21.0
# ...    ...         ...                    ...                   ...   ...
# 2452  2405        1100  Finance & Investments        Christian Herz   NaN
# 2453  2405        1100  Finance & Investments         Michaela Herz   NaN
# 2550  2540        1000              Logistics        Chang Kuo-Ming   NaN
# 2603  2540        1000          Manufacturing     Gabriella Meister   NaN
# 2609  2540        1000       Fashion & Retail          Réal Plourde   NaN
#
#       country               city              source             industries  \
# 823     Italy              Milan           Eyeglases       Fashion & Retail
# 1755      NaN                NaN       Online gaming  Media & Entertainment
# 1334      NaN                NaN          Drugstores       Fashion & Retail
# 825     Italy              Milan          Eyeglasses       Fashion & Retail
# 1754      NaN                NaN       Online gaming  Media & Entertainment
# ...       ...                ...                 ...                    ...
# 2452  Germany            Hamburg              Coffee  Finance & Investments
# 2453  Germany            Hamburg              Coffee  Finance & Investments
# 2550   Taiwan             Taipei      Transportation              Logistics
# 2603  Germany  Landsberg am Lech          Appliances          Manufacturing
# 2609   Canada          Westmount  Convenience stores       Fashion & Retail
#
#      countryOfCitizenship  ... cpi_change_country          gdp_country  \
# 823                 Italy  ...                0.6  $2,001,244,392,042
# 1755          South Korea  ...                NaN                  NaN
# 1334              Germany  ...                NaN                  NaN
# 825                 Italy  ...                0.6  $2,001,244,392,042
# 1754          South Korea  ...                NaN                  NaN
# ...                   ...  ...                ...                  ...
# 2452              Germany  ...                1.4  $3,845,630,030,824
# 2453              Germany  ...                1.4  $3,845,630,030,824
# 2550               Taiwan  ...                NaN                  NaN
# 2603              Germany  ...                1.4  $3,845,630,030,824
# 2609               Canada  ...                1.9  $1,736,425,629,520
#
#      gross_tertiary_education_enrollment  \
# 823                                 61.9
# 1755                                 NaN
# 1334                                 NaN
# 825                                 61.9
# 1754                                 NaN
# ...                                  ...
# 2452                                70.2
# 2453                                70.2
# 2550                                 NaN
# 2603                                70.2
# 2609                                68.9
#
#      gross_primary_education_enrollment_country life_expectancy_country  \
# 823                                       101.9                    82.9
# 1755                                        NaN                     NaN
# 1334                                        NaN                     NaN
# 825                                       101.9                    82.9
# 1754                                        NaN                     NaN
# ...                                         ...                     ...
# 2452                                      104.0                    80.9
# 2453                                      104.0                    80.9
# 2550                                        NaN                     NaN
# 2603                                      104.0                    80.9
# 2609                                      100.9                    81.9
#
#      tax_revenue_country_country total_tax_rate_country population_country  \
# 823                         24.3                   59.1         60297396.0
# 1755                         NaN                    NaN                NaN
# 1334                         NaN                    NaN                NaN
# 825                         24.3                   59.1         60297396.0
# 1754                         NaN                    NaN                NaN
# ...                          ...                    ...                ...
# 2452                        11.5                   48.8         83132799.0
# 2453                        11.5                   48.8         83132799.0
# 2550                         NaN                    NaN                NaN
# 2603                        11.5                   48.8         83132799.0
# 2609                        12.8                   24.5         36991981.0
#
#      latitude_country longitude_country
# 823         41.871940         12.567380
# 1755              NaN               NaN
# 1334              NaN               NaN
# 825         41.871940         12.567380
# 1754              NaN               NaN
# ...               ...               ...
# 2452        51.165691         10.451526
# 2453        51.165691         10.451526
# 2550              NaN               NaN
# 2603        51.165691         10.451526
# 2609        56.130366       -106.346771
#
# [2640 rows x 35 columns]

# %%
# 2 of the youngest billionaires in the world are both from Italy and in the Fashion and Retail industry

# %%
df["country"].value_counts()
# Out:
# United States           754
# China                   523
# India                   157
# Germany                 102
# United Kingdom           82
#                        ...
# Portugal                  1
# Georgia                   1
# Eswatini (Swaziland)      1
# Uzbekistan                1
# Armenia                   1
# Name: country, Length: 78, dtype: int64

# %%
# We can see the US, China, India, Germany and the UK are the top 5 countries with the most billionaires

# %%
df["category"].value_counts()
# Out:
# Finance & Investments         372
# Manufacturing                 324
# Technology                    314
# Fashion & Retail              266
# Food & Beverage               212
# Healthcare                    201
# Real Estate                   193
# Diversified                   187
# Energy                        100
# Media & Entertainment          91
# Metals & Mining                74
# Automotive                     73
# Service                        53
# Construction & Engineering     45
# Logistics                      40
# Sports                         39
# Telecom                        31
# Gambling & Casinos             25
# Name: category, dtype: int64

# %%
# Finance & Investments, Manufacturing, Technology, Fashion & Retail, and Food & Beverage form the top 5 most common billionaire industries

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
top_10_industries = df["category"].value_counts().head(10)

# %%
top_10_industries
# Out:
# Finance & Investments    372
# Manufacturing            324
# Technology               314
# Fashion & Retail         266
# Food & Beverage          212
# Healthcare               201
# Real Estate              193
# Diversified              187
# Energy                   100
# Media & Entertainment     91
# Name: category, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_industries.values, y=top_10_industries.index, palette="viridis")
plt.xlabel("Number of Billionaires")
plt.ylabel("Industry")
plt.title("Top 10 Industries with the Most Billionaires")
plt.show()

# %%
top_10_countries = df["country"].value_counts().head(10)

# %%
top_10_countries
# Out:
# United States     754
# China             523
# India             157
# Germany           102
# United Kingdom     82
# Russia             79
# Switzerland        78
# Hong Kong          68
# Italy              55
# Singapore          46
# Name: country, dtype: int64

# %%
plt.figure(figsize=(12, 6))
colors = sns.color_palette("pastel")
sns.barplot(x=top_10_countries.values, y=top_10_countries.index, palette="muted")

for i, v in enumerate(top_10_countries.values):
    plt.text(v + 1, i, str(v), color="black", va="center")

plt.xlabel("Number of Billionaires")
plt.ylabel("Country")
plt.title("Top 10 Countries with the Most Billionaires")
plt.xticks(rotation=45)
plt.show()
